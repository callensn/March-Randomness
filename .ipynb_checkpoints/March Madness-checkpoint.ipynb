# %%
import numpy as np

# %%
def PickWinner(teams, prob=.5):
    """
    Function that randomly selects the winner of a game.
    
    teams: list (2,) of two teams playing each other
    prob: float of how likely it is historically that the first team listed 
    in teams wins the game.
    """

    if np.random.rand() < prob: #If the random number between 0 and 1 is less than the 
        return teams[0]         #specified probability, then return the first team listed
    else:
        return teams[1]
    
def Bracket():
    bracket = [["Gonzaga", "Georgia St."], ["Boise St.", "Memphis"], ["Uconn", "NMSU"], ["Arkansas", "Vermont"], \
              ["Alabama", "Rutgers/ND"], ["Texas Tech", "Montana St."], ["Michigan St.", "Davidson"], ["Duke", "CSU"], \
              ["Baylor", "Norfolk St."], ["North Carolina", "Marquette"], ["Saint Mary's", "Wyoming"], ["UCLA", "Akron"], \
              ["Texas", "Virginia Tech"], ["Purdue", "Yale"], ["Murray St.", "SFU"], ["Kentucky", "St. Peters"], \
              ["Arizona", "Wright St."], ["Seton Hall", "TCU"], ["Houston", "UAB"], ["Illinois", "Chatanooga"], \
              ["Colorado St.", "Michigan"], ["Tennessee", "Longwood"], ["Ohio St.", "Loyola Chicago"], ["Villanova", "Delaware"], \
              ["Kansas", "TX Southern"], ["SDSU", "Creighton"], ["Iowa", "Richmond"], ["Providence", "South Dakota St."], \
              ["LSU", "Iowa St."], ["Wisconsin", "Colgate"], ["USC", "Miami"], ["Auburn", "Jacksonville St."]]
    return bracket

def NextRound(bracket, filename, num_round):
    
    if num_round == 2:
        with open(filename, 'a') as myfile:
            myfile.write("SWEET SIXTEEN: \n")
    elif num_round == 3:
        with open(filename, 'a') as myfile:
            myfile.write("ELITE EIGHT: \n")
    elif num_round == 4:
        with open(filename, 'a') as myfile:
            myfile.write("FINAL FOUR: \n")
    elif num_round == 5:
        with open(filename, 'a') as myfile:
            myfile.write("NATIONAL CHAMPIONSHIP: \n")
            
    if len(bracket) == 1:
        with open(filename, 'a') as myfile:
            myfile.write("NATIONAL CHAMPION: \n")
            myfile.write(bracket[0][0])
        return 
    else:
        next_bracket = []
        for i in range(0, len(bracket), 2):
            two = [PickWinner(bracket[i]), PickWinner(bracket[i+1])]
            next_bracket.append(two)
            
            with open(filename, 'a') as myfile:
                for team in two:
                    myfile.write(team)
                    myfile.write("\n")
                    
        return NextRound(next_bracket, filename, num_round + 1)

    
def FirstRound(initial_bracket):
    second_round = []
    real_second_round = []
    for i in range(len(initial_bracket)):
        second_round.append(PickWinner(initial_bracket[i], prob=seed(i)))
    
    for i in range(0,len(second_round),2):
        real_second_round.append([second_round[i], second_round[i+1]])
    return real_second_round
        
        
def seed(i):
    if i in [0,8,16,24]:
        return .992
    elif i in [1,9,17,25]:
        return .5
    elif i in [2,10,18,26]:
        return .65
    elif i in [3,11,19,27]:
        return .645
    elif i in [4,12,20,28]:
        return .625
    elif i in [5,13,21,29]:
        return .85
    elif i in [6,14,22,30]:
        return .6
    elif i in [7,15,23,31]:
        return .938

# %%
def read_file(filename):
    second = []
    sweet = []
    elite = []
    four = []
    final = []
    champ = []

    with open(filename, 'r') as myfile:
        line = myfile.readline()
        teams = []
        while line != "SWEET SIXTEEN:":
            line = myfile.readline().strip()
            second.append(line)
        second.pop()
        
        while line != "ELITE EIGHT:":
            line = myfile.readline().strip()
            sweet.append(line)
        sweet.pop()
        
        while line != "FINAL FOUR:":
            line = myfile.readline().strip()
            elite.append(line)
        elite.pop()
        
        while line != "NATIONAL CHAMPIONSHIP:":
            line = myfile.readline().strip()
            four.append(line)
        four.pop()
        
        while line != "NATIONAL CHAMPION:":
            line = myfile.readline().strip()
            final.append(line)
        final.pop()
        champ.append(myfile.readline().strip())
    
    totals = [second, sweet, elite, four, final, champ]
    return totals

def accuracy(totals, my_picks):
    round_accuracy = []
    rounds = len(my_picks)
    total_acc = 0
    total_length = 0
    game_acc = 0
    for i in range(rounds):
        acc = 0
        total_length += len(my_picks[i])
        
        for j in range(0,len(my_picks[i]),2):
            if my_picks[i][j] in totals[i] and my_picks[i][j+1] in totals[i]:
                game_acc += 1
                acc += 2
                total_acc += 2
            elif my_picks[i][j] in totals[i] or my_picks[i][j+1] in totals[i]:
                acc += 1
                total_acc += 1
            else:
                acc += 0
                total_acc += 0
        round_accuracy.append(acc/len(totals[i]))
        
    return round_accuracy, total_acc/total_length, game_acc/(total_length/2)

# %%
#long_total = read_file("round1.txt")

# %%
mine = [['Gonzaga', 'Memphis', 'Uconn', 'Vermont', 'Alabama', 'Texas Tech', 'Michigan St.', 'Duke', 'Baylor', \
        'North Carolina', 'Wyoming', 'Akron', 'Texas', 'Yale', 'Murray St.', 'Kentucky', 'Arizona', 'TCU', 'Houston', \
        'Chatanooga', 'Colorado St.', 'Tennessee', 'Ohio St.', 'Delaware', 'Kansas', 'Creighton', 'Richmond', \
        'Providence', 'Iowa St.', 'Colgate', 'Miami', 'Auburn'], ['Memphis', 'Uconn', 'Alabama', 'Duke', \
                                                                  'North Carolina', 'UCLA', 'Purdue', 'Kentucky', \
                                                                  'Arizona', 'Chatanooga', 'Tennessee', 'Ohio St.', \
                                                                  'Kansas', 'Richmond', 'Colgate', 'Miami']]

# %%
def generate():
    for i in range(2000):
        initial_bracket = Bracket()
        testrun = FirstRound(initial_bracket)
        filename = "round" + str(i) + ".txt"
        with open(filename, 'w') as myfile:
            myfile.write("SECOND ROUND: \n")
            for game in testrun:
                for i in range(2):
                    myfile.write(game[i])
                    myfile.write("\n")
        NextRound(testrun, filename, 2)

# %%
generate()

# %%
def score_all(actual):
    accuracies = []
    for i in range(2000):
        long_total = read_file("round"+str(i)+".txt")
        accuracies.append(accuracy(long_total, actual))
    
    rounds = [tup[0] for tup in accuracies]
    percents = [tup[1:] for tup in accuracies]
    perc_arr = np.array(percents).reshape(2000,2)
    return rounds, perc_arr

# %%
#The list "mine" represents the actual outcomes every round
#This will have to be updated every round and run again to get complete
#scores per round of how the random brackets are doing.
#r_score, p_scores = score_all(mine)
